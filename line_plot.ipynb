# %%
import numpy as np
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objects as go

# %%
df = pd.read_csv("./DataFolder/AirQualityUCI.csv", delimiter=";", decimal=",")
df = df.drop(["Unnamed: 15","Unnamed: 16"], axis=1)
df.dropna(inplace=True)
df.head(5)
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH
# 0  13.6  48.9  0.7578
# 1  13.3  47.7  0.7255
# 2  11.9  54.0  0.7502
# 3  11.0  60.0  0.7867
# ...

# %%
df['Date'] = df['Date'].astype(str)
df['Time'] = df['Time'].astype(str)
df['Date_time'] = pd.to_datetime(df['Date']+df['Time'] , format="%d/%m/%Y%H.%M.%S")
df.head()
# Out:
#          Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  10/03/2004  18.00.00     2.6       1360.0     150.0      11.9
# 1  10/03/2004  19.00.00     2.0       1292.0     112.0       9.4
# 2  10/03/2004  20.00.00     2.2       1402.0      88.0       9.0
# 3  10/03/2004  21.00.00     2.2       1376.0      80.0       9.2
# 4  10/03/2004  22.00.00     1.6       1272.0      51.0       6.5
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# 2          939.0    131.0        1140.0    114.0        1555.0       1074.0
# 3          948.0    172.0        1092.0    122.0        1584.0       1203.0
# 4          836.0    131.0        1205.0    116.0        1490.0       1110.0
#
#       T    RH      AH           Date_time
# 0  13.6  48.9  0.7578 2004-03-10 18:00:00
# ...

# %%
fig_obj = go.Scatter(x=df.Date_time, y=df['NOx(GT)'], mode='lines')
fig_layout = go.Layout(width=800, height=400,
                       title="Line Plot - Bill Amount Vs Tip Mount",
                       xaxis=dict(title="Billed Amount"),
                       yaxis=dict(title="Tips Amount"))
fig = go.Figure(fig_obj, layout=fig_layout)
fig.show()
# Out:
# <div>                            <div id="1feb69f2-e50a-4a7f-8052-c6da8ce904e2" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1feb69f2-e50a-4a7f-8052-c6da8ce904e2")) {                    Plotly.newPlot(                        "1feb69f2-e50a-4a7f-8052-c6da8ce904e2",                        [{"mode":"lines","x":["2004-03-10T18:00:00","2004-03-10T19:00:00","2004-03-10T20:00:00","2004-03-10T21:00:00","2004-03-10T22:00:00","2004-03-10T23:00:00","2004-03-11T00:00:00","2004-03-11T01:00:00","2004-03-11T02:00:00","2004-03-11T03:00:00","2004-03-11T04:00:00","2004-03-11T05:00:00","2004-03-11T06:00:00","2004-03-11T07:00:00","2004-03-11T08:00:00","2004-03-11T09:00:00","2004-03-11T10:00:00","2004-03-11T11:00:00","2004-03-11T12:00:00","2004-03-11T13:00:00","2004
# ...
